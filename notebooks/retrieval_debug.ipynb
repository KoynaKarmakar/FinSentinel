# %% [markdown]
# # FinSentinel — Retrieval Debugger
#
# Compare dense vs BM25 vs hybrid retrieval results for any query.

# %%
import sys
sys.path.insert(0, '..')
from app.retrieval.hybrid_retrieve import hybrid_retrieve

query = 'structuring transactions below reporting threshold PMLA section 12'
results = hybrid_retrieve(query)
for i, r in enumerate(results):
    print(f'\n--- Rank {i+1} (score: {r["rerank_score"]:.4f}) ---')
    print(r['text'][:200])
