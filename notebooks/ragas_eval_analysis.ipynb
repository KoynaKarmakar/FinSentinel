# %% [markdown]
# # FinSentinel — RAGAS Evaluation Analysis
#
# Run this notebook after indexing documents and running investigations.

# %%
import sys
sys.path.insert(0, '..')
from app.evaluation.run_eval import run_tier_accuracy_eval, run_indicator_recall_eval

tier_results = run_tier_accuracy_eval()
print(f'Tier Accuracy: {tier_results["accuracy"]:.1%}')

ind_results = run_indicator_recall_eval()
print(f'Indicator Recall: {ind_results["indicator_recall"]:.1%}')
